# %% [markdown]
# # Problem Statement: Given above data build a machine learning model that can predict home prices based on square feet area

# %% [markdown]
# # Import the required libraries for Linear Regression

# %%
import pandas as pd # for data frame
import numpy as np # for mathemetical operation
import matplotlib.pyplot as plt # for vizualization
# %matplotlib inline
from sklearn.linear_model import LinearRegression #  For regression in Machine Learning
from sklearn.metrics import r2_score # For Accuracy

# %% [markdown]
# # Import dataset

# %%
cd D:/Fingertips_Shalini/Desktop/Data Files

# %%
pwd

# %%
df=pd.read_csv("ML Simple Linear Regression Resource16931312390.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %% [markdown]
# #  Plot the dependent and independent variables

# %%
plt.xlabel('area')
plt.ylabel('price')
plt.title('Area v/s Price')
plt.plot(df.area,df.price,color='red',marker='+')
plt.show()

# %%
plt.xlabel('area')
plt.ylabel('price')
plt.title('Area v/s Price')
plt.plot(df.area,df.price,color='red',marker='+')
plt.show()

# %% [markdown]
# # Model initialization

# %% [raw]
# #  divide the data into “attributes” and “labels”.
# # Attributes are the independent variables while labels are dependent variables
# # whose values are to be predicteddivide the data into “attributes” and “labels”.

# %%
area=df.drop('price',axis='columns')
area
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
price=df.price
price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %% [markdown]
# # Model Intilization

# %%
# Making an object names regression_model

# %%
regression_model = LinearRegression()

# %% [markdown]
# # Fit the data(train the model-independent,dependent variable-target variable)

# %%
# always keep the indepent variable first and then dependent varible

# %%
# fit function for training the model

# %%
regression_model.fit(area,price)
# Out:
# LinearRegression()

# %% [markdown]
# # Predict price of home with 3000 sq ft and 5500 sq ft

# %%
#Predict functio to predict the price for given area

# %%
price_predicted = regression_model.predict([[3000]]) 
price_predicted
# Out:
# C:\Users\kashy\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([587979.45205479])

# %%
price_predicted = regression_model.predict([[5000]])
price_predicted
# Out:
# C:\Users\kashy\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %% [markdown]
# # y=mx+b

# %%
3000*135.78767123+180616.43835616432
# Out:
# 587979.4520461643

# %%
price_predicted_2 = regression_model.predict([[5000]]) 
price_predicted_2
# Out:
# C:\Users\kashy\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
price_predicted_3 = regression_model.predict([[4000]]) 
price_predicted_3
# Out:
# C:\Users\kashy\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([723767.12328767])

# %% [markdown]
# # Slope and Intercept

# %%
print('Slope:' ,regression_model.coef_) 
print('Intercept:', regression_model.intercept_)
# Out:
# Slope: [135.78767123]
# Intercept: 180616.43835616432

# %%
price_predicted=regression_model.predict([[5500]])
price_predicted
# Out:
# C:\Users\kashy\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([927448.63013699])

# %%
price_predicted=regression_model.predict(area)
price_predicted
# Out:
# array([533664.38356164, 587979.45205479, 615136.98630137, 669452.05479452,
#        723767.12328767])

# %%
df.price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %% [markdown]
# # Model evaluation

# %%
r2=r2_score(price,price_predicted)
r2
# Out:
# 0.9584301138199486

# %% [markdown]
# # Print Values

# %%
print('Slope:' ,regression_model.coef_) 
print('Intercept:', regression_model.intercept_) 
print('R2 score: ', r2)
# Out:
# Slope: [135.78767123]
# Intercept: 180616.43835616432
# R2 score:  0.9584301138199486

# %% [markdown]
# # Our regression line has fit -96% accuracy of the model is 96%

# %% [markdown]
# # Show the fit line on preicted values

# %%
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red',s=10)


# Predicted value
plt.scatter(df.area,price_predicted,color='green',marker='+')
plt.show()

# %% [markdown]
# # Generate CSV file with list of home price predictions¶

# %%
area_df = pd.read_excel('area.xlsx')
area_df
# Out:
#             area
# 0    1400.000000
# 1    1500.000000
# 2    2000.000000
# 3    2500.000000
# 4    3000.000000
# 5    3500.000000
# 6    4000.000000
# 7    4385.714286
# 8    4842.857143
# 9    5300.000000
# 10   5757.142857
# 11   6214.285714
# 12   6671.428571
# 13   7128.571429
# 14   7585.714286
# 15   8042.857143
# 16   8500.000000
# 17   8957.142857
# 18   9414.285714
# 19   9871.428571
# 20  10328.571429
# 21  10785.714286
# 22  11242.857143
# 23  11700.000000

# %%
p=regression_model.predict(area_df)
p
# Out:
# array([ 370719.17808219,  384297.94520548,  452191.78082192,
#         520085.61643836,  587979.45205479,  655873.28767123,
#         723767.12328767,  776142.36790607,  838216.73189824,
#         900291.09589041,  962365.45988258, 1024439.82387476,
#        1086514.18786693, 1148588.5518591 , 1210662.91585127,
#        1272737.27984345, 1334811.64383562, 1396886.00782779,
#        1458960.37181996, 1521034.73581213, 1583109.0998043 ,
#        1645183.46379648, 1707257.82778866, 1769332.19178082])

# %% [markdown]
# # Add Price column

# %%
area_df['prices']=p
area_df
# Out:
#             area        prices
# 0    1400.000000  3.707192e+05
# 1    1500.000000  3.842979e+05
# 2    2000.000000  4.521918e+05
# 3    2500.000000  5.200856e+05
# 4    3000.000000  5.879795e+05
# 5    3500.000000  6.558733e+05
# 6    4000.000000  7.237671e+05
# 7    4385.714286  7.761424e+05
# 8    4842.857143  8.382167e+05
# 9    5300.000000  9.002911e+05
# 10   5757.142857  9.623655e+05
# 11   6214.285714  1.024440e+06
# 12   6671.428571  1.086514e+06
# 13   7128.571429  1.148589e+06
# 14   7585.714286  1.210663e+06
# 15   8042.857143  1.272737e+06
# 16   8500.000000  1.334812e+06
# 17   8957.142857  1.396886e+06
# 18   9414.285714  1.458960e+06
# 19   9871.428571  1.521035e+06
# 20  10328.571429  1.583109e+06
# 21  10785.714286  1.645183e+06
# 22  11242.857143  1.707258e+06
# 23  11700.000000  1.769332e+06

# %% [markdown]
# # Export csv file to directory

# %%
area_df.to_csv("priceprediction.csv")
